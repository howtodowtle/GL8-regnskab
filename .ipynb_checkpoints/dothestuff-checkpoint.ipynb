# %% [markdown]
# # Aktuelt regnskab

# %% [markdown]
# ### 1. Import the relevant Gorgi methods:

# %%
import gorgireader
import gorgimessages
import opslaget

# %% [markdown]
# Methods at our disposal:
#
# + **`getWorkbook()`** from `gorgireader` returns a pandas dataframe
# + **`createAllMessages(df, month, year, dates, deadline, who = range(1, 24))`** from `gorgimessages` prints all (or selected) messages
# + **`createOpslagetEN(month, year, dates)`** or **`createOpslagetDK(month, year, dates)`** from `opslaget` create a facebook posting

# %% [markdown]
# ### 2. Set values:

# %%
# only define path when different than 
# D:/Dropbox/Egmont/Regnskab/Aktuelt Regnskab/gangregnskab_egmontgl8.xlsx
df = gorgireader.getWorkbook()
month = "august"
year = "2017"
# dates format: "2/7/2017-2/8/2017", or however you would like it to look
dates = "2/8/2017-31/8/2017"
deadline = "14/9"

# %% [markdown]
# ### 3. Create the facebook posting:

# %%
opslag = opslaget.createOpslagetDK(month, year, dates)
# or, in English:
# opslag = opslaget.createOpslagetEN(month, year, dates)
# Out:
# GANGREGNSKAB august 2017 (2/8/2017-31/8/2017)
#
# Hej venner,
#
# det nye gangregnskab er oppe!
#
# Tjek jeres ny saldo i den grøn kolonne. Hvis saldoen er under 300 kr. så skal i overføre til gangkontoen i løbet af to uger (ellers ryger der 5 procent strafrente). Beløbet i skal overføre står i kolonnen helt til højre.
#
# Mit freundlichen Grüßen
# /801.
#
# Vores gangkonto: Reg. 2104 Kto. 4391 845 196 (kan også findes i informationen af facebook gruppen).

# %% [markdown]
# ### 4. Create the messages:

# %%
beskeder = gorgimessages.createAllMessages(df, month, year, dates, deadline)
# Out:
# Hej Alex,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +762 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Sofie,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +356 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Amalie,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +99 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 201 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Oskar,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +525 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Jakob,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +993 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Mads,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +497 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Morten,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -481 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 781 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Celine,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -659 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 959 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Henrik,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -507 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 807 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Astrid,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -103 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 403 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Michael P,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +1398 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Niels Emil,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +852 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Frederik,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -251 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 551 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Torkil,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -310 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 610 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Anne,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +402 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Xenia,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +722 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Lasse,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +257 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 43 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Louise,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +1611 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Laura,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +684 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Michael HG,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -312 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 612 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Carolina,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +0 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 300 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Benjamin,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -242 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 542 kr. til gangkontoen inden d. 14/9.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Maria,
#
# regnskabet for august 2017 (2/8/2017-31/8/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +704 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****

# %% [markdown]
# ### 5. Create the plot:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
regnskab = gorgireader.getWorkbook()
gorgimessages.whichMessage(regnskab)
# Out:
#    nummer        name gammel_saldo   ind  forbrug  ny_saldo transfer  msg_type
# 1     801        Alex       232.43   500  29.9091   762.339      NaN         1
# 2     802       Sofie      365.962   NaN -9.48091   356.481      NaN         1
# 3     803      Amalie      470.035   NaN -371.171   98.8643  201.136         0
# 4     804       Oskar       150.83   820 -445.841   524.989      NaN         1
# 5     805       Jakob       286.01  1200 -492.971   993.039      NaN         1
# 6     806        Mads       677.85   NaN -181.191   496.659      NaN         1
# 7     807      Morten      145.377   NaN -626.671  -481.293  781.293        -1
# 8     808      Celine     -524.126   NaN -134.747  -658.873  958.873        -1
# 9     809      Henrik      51.7007   NaN -558.891   -507.19   807.19        -1
# 10    810      Astrid       170.68   NaN -274.131  -103.451  403.451        -1
# 11    811   Michael P      2037.83   NaN -639.781   1398.05      NaN         1
# 12    812  Niels Emil      1041.66   NaN -190.031   851.629      NaN         1
# 13    814    Frederik     -360.225   NaN  108.968  -251.258  551.258        -1
# 14    815      Torkil      9.36018   NaN -319.101  -309.741  609.741        -1
# 15    816        Anne      505.481   NaN -103.621    401.86      NaN         1
# 16    817       Xenia       838.81   NaN -116.741   722.069      NaN         1
# 17    818       Lasse       544.71   NaN -287.481   257.229  42.7707         0
# 18    819      Louise     -328.465  1000  939.479   1611.01      NaN         1
# 19    820       Laura       997.44   NaN -313.711   683.729      NaN         1
# 20    821  Michael HG      132.671   NaN -444.791   -312.12   612.12        -1
# 21    822    Carolina    -0.361843   NaN        0 -0.361843  300.362         0
# 22    823    Benjamin      39.4502   NaN -281.271  -241.821  541.821        -1
# 23    824       Maria      891.855   NaN -187.541   704.314      NaN         1

# %%
fig, ax = plt.subplots(figsize = (12, 8))

ax.barh(range(1, 24), regnskab["ny_saldo"], align = 'center', 
        color = regnskab.msg_type.map({-1: "r", 0: "0.75", 1: "g"}), ecolor = 'black')
#plt.axis([-2050, 2050, -1, 25])
ax.set_yticks(range(1, 24))
ax.set_yticklabels(regnskab["name"])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Din saldo')
plt.vlines(0, ymin = 0, ymax = 24, colors = 'k', linestyles = '-')
plt.vlines(300, ymin = 0, ymax = 24, colors = 'k', linestyles = ':')
ax.set_title('Venligst overfør op til +300 kr. (eller mere)')

for i, v in enumerate(regnskab["ny_saldo"]):
    ax.text(v + 20, i + 1.2, str(round(v)), color="k")

plt.show()
