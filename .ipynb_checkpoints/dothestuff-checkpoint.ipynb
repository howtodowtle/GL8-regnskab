# %% [markdown]
# # Aktuelt regnskab

# %% [markdown]
# ### 1. Import the relevant Gorgi methods:

# %%
import gorgireader
import gorgimessages
import opslaget

# %% [markdown]
# Methods at our disposal:
#
# + **`getWorkbook()`** from `gorgireader` returns a pandas dataframe
# + **`createAllMessages(df, month, year, dates, deadline, who = range(1, 24))`** from `gorgimessages` prints all (or selected) messages
# + **`createOpslagetEN(month, year, dates)`** or **`createOpslagetDK(month, year, dates)`** from `opslaget` create a facebook posting

# %% [markdown]
# ### 2. Set values:

# %%
# only define path when different than 
# D:/Dropbox/Egmont/Regnskab/Aktuelt Regnskab/gangregnskab_egmontgl8.xlsx
df = gorgireader.getWorkbook()
month = "oktober"
year = "2017"
# dates format: "2/7/2017-2/8/2017", or however you would like it to look
dates = "11/10/2017-29/10/2017"
deadline = "12/11"

# %% [markdown]
# ### 3. Create the facebook posting:

# %%
opslag = opslaget.createOpslagetDK(month, year, dates)
# or, in English:
# opslag = opslaget.createOpslagetEN(month, year, dates)
# Out:
# GANGREGNSKAB oktober 2017 (11/10/2017-29/10/2017)
#
# Hej venner,
#
# det nye gangregnskab er oppe!
#
# Tjek jeres ny saldo i den grøn kolonne. Hvis saldoen er under 300 kr. så skal i overføre til gangkontoen i løbet af to uger (ellers ryger der 5 procent strafrente). Beløbet i skal overføre står i kolonnen helt til højre.
#
# Mit freundlichen Grüßen
# /801.
#
# Vores gangkonto: Reg. 2104 Kto. 4391 845 196 (kan også findes i informationen af facebook gruppen).

# %% [markdown]
# ### 4. Create the messages:

# %%
beskeder = gorgimessages.createAllMessages(df, month, year, dates, deadline)
# Out:
# Hej Alex,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +655 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Sofie,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +993 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Amalie,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +466 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Oskar,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +841 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Jakob,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +502 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Mads,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +281 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 19 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Morten,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +652 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Celine,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +11 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 289 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Henrik,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -390 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 690 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Astrid,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -181 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 481 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Karolina,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +356 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Niels Emil,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +338 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Frederik,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -189 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 489 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Torkil,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -40 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 340 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Anne,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +216 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 84 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Xenia,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +906 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Lasse,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -140 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 440 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Louise,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +671 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Laura,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +144 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 156 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Michael HG,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +50 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 250 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, eller hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Carolina,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er -341 kr.
#
# Da alle skal være mindst 300 kr. i plus bedes du overføre 641 kr. til gangkontoen inden d. 12/11.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# Kh /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****
#
# Hej Maria,
#
# regnskabet for oktober 2017 (11/10/2017-29/10/2017) er oppe i facebook gruppen.
#
# Din nye saldo er +873 kr.
#
# Du kan se detaljerne på de forskellige screenshots i gruppen.
#
# Skriv til mig hvis jeg har glemt et eller andet, og hvis du har spørgsmål!
#
# /801 Alex
#
# Gangkonto: Reg. 2104 Kto. 4391 845 196
#
# ****

# %% [markdown]
# ### 5. Create the plot:

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

# %%
regnskab = gorgireader.getWorkbook()
gorgimessages.whichMessage(regnskab)
# Out:
#    nummer        name gammel_saldo   ind  forbrug ny_saldo transfer  msg_type
# 1     801        Alex      415.632  -500   738.98  654.612      NaN         1
# 2     802       Sofie      815.064   NaN  177.839  992.903      NaN         1
# 3     803      Amalie      709.377   NaN -242.961  466.416      NaN         1
# 4     804       Oskar      437.682   NaN  403.339  841.021      NaN         1
# 5     805       Jakob      544.142   NaN -41.9714  502.171      NaN         1
# 6     806        Mads      78.9819   221 -19.1614  280.821  19.1795         0
# 7     807      Morten     -879.466  1500  31.4686  652.003      NaN         1
# 8     808      Celine     -863.954  1000 -125.161  10.8843  289.116         0
# 9     809      Henrik      108.473   NaN -498.051 -389.578  689.578        -1
# 10    810      Astrid      57.0793   NaN -238.161 -181.082  481.082        -1
# 11    811    Karolina       -478.5  1000 -165.491  356.009      NaN         1
# 12    812  Niels Emil      688.962   NaN -351.151  337.811      NaN         1
# 13    814    Frederik     -192.118   NaN  3.52274 -188.595  488.595        -1
# 14    815      Torkil     -358.255   500 -181.531 -39.7865  339.787        -1
# 15    816        Anne      177.762   200 -161.761  216.001  83.9989         0
# 16    817       Xenia      801.472   NaN  104.819  906.291      NaN         1
# 17    818       Lasse      54.5119   245 -439.761 -140.249  440.249        -1
# 18    819      Louise       1134.3   NaN -463.781  670.515      NaN         1
# 19    820       Laura      277.912   NaN -133.801  144.111  155.889         0
# 20    821  Michael HG      154.012   NaN -103.561  50.4511  249.549         0
# 21    822    Carolina     -169.829   NaN -171.143 -340.972  640.972        -1
# 22    824       Maria      863.146   NaN  9.83864  872.985      NaN         1

# %%
beboertal = 22

fig, ax = plt.subplots(figsize = (12, 8))

ax.barh(range(1, beboertal + 1), regnskab["ny_saldo"], align = 'center', 
        color = regnskab.msg_type.map({-1: "r", 0: "0.75", 1: "g"}), ecolor = 'black')
#plt.axis([-2050, 2050, -1, 25])
ax.set_yticks(range(1, beboertal + 1))
ax.set_yticklabels(regnskab["name"])
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Din saldo')
plt.vlines(0, ymin = 0, ymax = beboertal + 1, colors = 'k', linestyles = '-')
plt.vlines(300, ymin = 0, ymax = beboertal + 1, colors = 'k', linestyles = ':')
ax.set_title('Venligst overfør op til +300 kr. (eller mere)')

for i, v in enumerate(regnskab["ny_saldo"]):
    ax.text(v + 20, i + 1.2, str(round(v)), color = "k")

plt.show()
